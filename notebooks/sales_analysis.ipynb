# %%
import pandas as pd

df = pd.read_csv("../data/processed_sales.csv")

df.head()
# Out:
#    order_id customer_id   product     category  quantity    price        date  \
# 0       713        C040  Keyboard  Electronics         2   2000.0  03/01/2025
# 1       553        C077     Table    Furniture         2  12500.0  2025-11-28
# 2       513        C185     Phone   Furniture          3  30000.0  2025-02-27
# 3       766        C052  Keyboard  Electronics         5   2000.0  08/05/2025
# 4       780        C164  Keyboard  Electronics         3   2000.0  2025-11-24
#
#    revenue
# 0   4000.0
# 1  25000.0
# 2  90000.0
# 3  10000.0
# 4   6000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     632 non-null    int64
#  1   customer_id  632 non-null    object
#  2   product      632 non-null    object
#  3   category     632 non-null    object
#  4   quantity     632 non-null    int64
#  5   price        632 non-null    float64
#  6   date         632 non-null    object
#  7   revenue      632 non-null    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 39.6+ KB

# %%
df.describe()
# Out:
#          order_id    quantity          price       revenue
# count  632.000000  632.000000     632.000000  6.320000e+02
# mean   449.531646    2.919304   32019.753165  8.936672e+04
# std    202.070422    1.687506  114535.358490  4.122379e+05
# min    101.000000   -5.000000    1000.000000 -3.580080e+06
# 25%    274.750000    2.000000    4000.000000  9.000000e+03
# 50%    447.500000    3.000000   11500.000000  2.500000e+04
# 75%    626.500000    4.000000   25000.000000  6.000000e+04
# max    800.000000    5.000000  997235.000000  4.086070e+06

# %%
total_sales = df["revenue"].sum()

print(total_sales)
# Out:
# 56479768.0

# %%
#Best Selling Products
product_sales = (
    df.groupby("product")["revenue"]
    .sum()
    .sort_values(ascending=False)
)

product_sales
# Out:
# product
# Laptop        12267365.0
# Phone          8142880.0
# Desk           7723120.0
# Chair          6677972.0
# Table          5749150.0
# Monitor        5678072.0
# Sofa           3368000.0
# Headphones     3087336.0
# Webcam         2841883.0
# Keyboard        805990.0
# Mouse           138000.0
# Name: revenue, dtype: float64

# %%
#Category Analysis
category_sales = (
    df.groupby("category")["revenue"]
    .sum()
)
category_sales
# Out:
# category
#  Furniture       1231000.0
#  electronics     2466883.0
# Elec              185000.0
# Electronics     29033643.0
# Electronics       404000.0
# Furniture       22833242.0
# furnitur          326000.0
# Name: revenue, dtype: float64

# %%
import matplotlib.pyplot as plt


product_sales.plot(
    kind="bar",
    title="Revenue by Product"
)

plt.show()
